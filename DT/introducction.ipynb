# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiziferr/machine_learning/blob/main/DT/introducction.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/joanby/python-ml-course/master/'\
'datasets/titanic/titanic3.csv'

data = pd.read_csv(url)
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %% [markdown]
# - *sep*: str = separador
# - *dtype*: dict = formatear columnas
# - *header*: int = indica cual es la fila que servira como encabezado
# - *names*: list = Permite nombrar las columnas
# - *skiprows*: int = la fila que se debe leer, se salta las anteriores
# - *skip_blank_lines*: bool = Pinta los nan o los deja vacios

# %%
data.dtypes
# Out:
# pclass         int64
# survived       int64
# name          object
# sex           object
# age          float64
# sibsp          int64
# parch          int64
# ticket        object
# fare         float64
# cabin         object
# embarked      object
# boat          object
# body         float64
# home.dest     object
# dtype: object

# %%
columns_example = data.columns.to_list()
columns_example
columns_example[1] = 'sobrevivio'

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1309 entries, 0 to 1308
# Data columns (total 14 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   pclass     1309 non-null   int64
#  1   survived   1309 non-null   int64
#  2   name       1309 non-null   object
#  3   sex        1309 non-null   object
#  4   age        1046 non-null   float64
#  5   sibsp      1309 non-null   int64
#  6   parch      1309 non-null   int64
#  7   ticket     1309 non-null   object
#  8   fare       1308 non-null   float64
#  9   cabin      295 non-null    object
#  10  embarked   1307 non-null   object
#  11  boat       486 non-null    object
#  12  body       121 non-null    float64
#  13  home.dest  745 non-null    object
# dtypes: float64(3), int64(4), object(7)
# memory usage: 143.3+ KB

# %%
data_t = pd.read_csv(
    url,
    sep=',',
    dtype={"pclass":float},
    header=0,
    names=columns_example,
    skip_blank_lines = True
    )

# %%
data_t.head()
# Out:
#    pclass  sobrevivio                                             name  \
# 0     1.0           1                    Allen, Miss. Elisabeth Walton
# 1     1.0           1                   Allison, Master. Hudson Trevor
# 2     1.0           0                     Allison, Miss. Helen Loraine
# 3     1.0           0             Allison, Mr. Hudson Joshua Creighton
# 4     1.0           0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
#
#       sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# 0  female  29.0000      0      0   24160  211.3375       B5        S    2
# 1    male   0.9167      1      2  113781  151.5500  C22 C26        S   11
# 2  female   2.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 3    male  30.0000      1      2  113781  151.5500  C22 C26        S  NaN
# 4  female  25.0000      1      2  113781  151.5500  C22 C26        S  NaN
#
#     body                        home.dest
# 0    NaN                     St Louis, MO
# ...

# %%
data_t.dtypes
# Out:
# pclass        float64
# sobrevivio      int64
# name           object
# sex            object
# age           float64
# sibsp           int64
# parch           int64
# ticket         object
# fare          float64
# cabin          object
# embarked       object
# boat           object
# body          float64
# home.dest      object
# dtype: object

# %%
# Open
path = './sample_data/california_housing_test.csv'
data = open(path, 'r')

# %%
cols = data.readline().strip().split(",")
cols
# Out:
# ['"longitude"',
#  '"latitude"',
#  '"housing_median_age"',
#  '"total_rooms"',
#  '"total_bedrooms"',
#  '"population"',
#  '"households"',
#  '"median_income"',
#  '"median_house_value"']

# %%
counter = 0
main_dict = {}

for col in cols:
  main_dict[col] = []

# %%
for line in data:
  values = line.strip().split(",")
  for i in range(len(cols)):
    main_dict[cols[i]].append(values[i])
  counter = counter + 1
print(f"The dataset has {counter} rows and {len(cols)}")
# Out:
# The dataset has 3000 rows and 9

# %%
with open(path, 'r') as infile:
  with open("./data/p.csv", "w") as outfile:
    for line in infile:
      fields = line.strip().split(",")
      outfile.write("\t".join(fields))
      outfile.write("\n")

# %%
date_test = pd.read_csv('./data/p.csv', sep='\t')
date_test
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2       -117.81     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
url = 'https://raw.githubusercontent.com/joanby/python-ml-course/master/'\
'datasets/titanic/titanic3.csv'

data = pd.read_csv(url)
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
# CSV
data.to_csv('./data/dta.csv')
# JSON
data.to_json('./data/dta.json')
# Excel
data.to_excel('./data/dta.xlsx')

# %%
import urllib3

# %%
url = 'https://raw.githubusercontent.com/Kaiziferr/datasets/main/diabetes.csv'

# %%
http = urllib3.PoolManager()
r = http.request('GET', url)

# %%
print('Status request code {}'.format(r.status))
# Out:
# Status request code 200

# %%
response = r.data

# %%
# string binarize to string utf-8
str_data = response.decode('utf-8')

# %%
str_data
# Out:
# 'Pregnancies,Glucose,BloodPressure,SkinThickness,Insulin,BMI,DiabetesPedigreeFunction,Age,Outcome\n6,148,72,35,0,33.6,0.627,50,1\n1,85,66,29,0,26.6,0.351,31,0\n8,183,64,0,0,23.3,0.672,32,1\n1,89,66,23,94,28.1,0.167,21,0\n0,137,40,35,168,43.1,2.288,33,1\n5,116,74,0,0,25.6,0.201,30,0\n3,78,50,32,88,31,0.248,26,1\n10,115,0,0,0,35.3,0.134,29,0\n2,197,70,45,543,30.5,0.158,53,1\n8,125,96,0,0,0,0.232,54,1\n4,110,92,0,0,37.6,0.191,30,0\n10,168,74,0,0,38,0.537,34,1\n10,139,80,0,0,27.1,1.441,57,0\n1,189,60,23,846,30.1,0.398,59,1\n5,166,72,19,175,25.8,0.587,51,1\n7,100,0,0,0,30,0.484,32,1\n0,118,84,47,230,45.8,0.551,31,1\n7,107,74,0,0,29.6,0.254,31,1\n1,103,30,38,83,43.3,0.183,33,0\n1,115,70,30,96,34.6,0.529,32,1\n3,126,88,41,235,39.3,0.704,27,0\n8,99,84,0,0,35.4,0.388,50,0\n7,196,90,0,0,39.8,0.451,41,1\n9,119,80,35,0,29,0.263,29,1\n11,143,94,33,146,36.6,0.254,51,1\n10,125,70,26,115,31.1,0.205,41,1\n7,147,76,0,0,39.4,0.257,43,1\n1,97,66,15,140,23.2,0.487,22,0\n13,145,82,19,110,22.2,0.245,57,0\n
# ...

# %%
# Data split to \n
lines = str_data.split('\n')

# %%
# Columns
columns_names = lines[0].split(',')
n_cols = len(columns_names)
n_cols, columns_names
# Out:
# (9,
#  ['Pregnancies',
#   'Glucose',
#   'BloodPressure',
#   'SkinThickness',
#   'Insulin',
#   'BMI',
#   'DiabetesPedigreeFunction',
#   'Age',
#   'Outcome'])

# %%
counter = 0
main_dict = {}
for i in range(n_cols):
  main_dict[columns_names[i]] = []

main_dict
# Out:
# {'Pregnancies': [],
#  'Glucose': [],
#  'BloodPressure': [],
#  'SkinThickness': [],
#  'Insulin': [],
#  'BMI': [],
#  'DiabetesPedigreeFunction': [],
#  'Age': [],
#  'Outcome': []}

# %%
for line in lines:
  if counter > 0:
    values = line.strip().split(',')
    for i, val in enumerate(values):
      main_dict[columns_names[i]].append(val)
  counter = counter + 1

# %%
data_medica = pd.DataFrame(main_dict)

# %%
print('The dataset has %d rows and %d columns'%(counter, n_cols))
# Out:
# The dataset has 769 rows and 9 columns

# %%
import os

# %%
mainpath = './data2'
filename = 'registros_medicos.'
fullpath = os.path.join(mainpath, filename)

# %%
data_medica.to_csv(f'{fullpath}.csv')
data_medica.to_json(f'{fullpath}.json')
data_medica.to_excel(f'{fullpath}.xlsx')

# %% [markdown]
# # **--Resume**

# %%
data.head()
# Out:
#    pclass  survived                                             name     sex  \
# 0       1         1                    Allen, Miss. Elisabeth Walton  female
# 1       1         1                   Allison, Master. Hudson Trevor    male
# 2       1         0                     Allison, Miss. Helen Loraine  female
# 3       1         0             Allison, Mr. Hudson Joshua Creighton    male
# 4       1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)  female
#
#        age  sibsp  parch  ticket      fare    cabin embarked boat   body  \
# 0  29.0000      0      0   24160  211.3375       B5        S    2    NaN
# 1   0.9167      1      2  113781  151.5500  C22 C26        S   11    NaN
# 2   2.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
# 3  30.0000      1      2  113781  151.5500  C22 C26        S  NaN  135.0
# 4  25.0000      1      2  113781  151.5500  C22 C26        S  NaN    NaN
#
#                          home.dest
# ...

# %%
data_medica.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Pregnancies               768 non-null    object
#  1   Glucose                   768 non-null    object
#  2   BloodPressure             768 non-null    object
#  3   SkinThickness             768 non-null    object
#  4   Insulin                   768 non-null    object
#  5   BMI                       768 non-null    object
#  6   DiabetesPedigreeFunction  768 non-null    object
#  7   Age                       768 non-null    object
#  8   Outcome                   768 non-null    object
# dtypes: object(9)
# memory usage: 54.1+ KB

# %%
data.shape, data.ndim
# Out:
# ((1309, 14), 2)

# %%
data.columns
# Out:
# Index(['pclass', 'survived', 'name', 'sex', 'age', 'sibsp', 'parch', 'ticket',
#        'fare', 'cabin', 'embarked', 'boat', 'body', 'home.dest'],
#       dtype='object')

# %%
data.describe()
# Out:
#             pclass     survived          age        sibsp        parch  \
# count  1309.000000  1309.000000  1046.000000  1309.000000  1309.000000
# mean      2.294882     0.381971    29.881135     0.498854     0.385027
# std       0.837836     0.486055    14.413500     1.041658     0.865560
# min       1.000000     0.000000     0.166700     0.000000     0.000000
# 25%       2.000000     0.000000    21.000000     0.000000     0.000000
# 50%       3.000000     0.000000    28.000000     0.000000     0.000000
# 75%       3.000000     1.000000    39.000000     1.000000     0.000000
# max       3.000000     1.000000    80.000000     8.000000     9.000000
#
#               fare        body
# count  1308.000000  121.000000
# mean     33.295479  160.809917
# std      51.758668   97.696922
# min       0.000000    1.000000
# 25%       7.895800   72.000000
# 50%      14.454200  155.000000
# 75%      31.275000  256.000000
# max     512.329200  328.000000

# %%
data.describe(include='object')
# Out:
#                         name   sex    ticket        cabin embarked boat  \
# count                   1309  1309      1309          295     1307  486
# unique                  1307     2       929          186        3   27
# top     Connolly, Miss. Kate  male  CA. 2343  C23 C25 C27        S   13
# freq                       2   843        11            6      914   39
#
#            home.dest
# count            745
# unique           369
# top     New York, NY
# freq              64

# %%
data.describe(include="all")
# Out:
#              pclass     survived                  name   sex          age  \
# count   1309.000000  1309.000000                  1309  1309  1046.000000
# unique          NaN          NaN                  1307     2          NaN
# top             NaN          NaN  Connolly, Miss. Kate  male          NaN
# freq            NaN          NaN                     2   843          NaN
# mean       2.294882     0.381971                   NaN   NaN    29.881135
# std        0.837836     0.486055                   NaN   NaN    14.413500
# min        1.000000     0.000000                   NaN   NaN     0.166700
# 25%        2.000000     0.000000                   NaN   NaN    21.000000
# 50%        3.000000     0.000000                   NaN   NaN    28.000000
# 75%        3.000000     1.000000                   NaN   NaN    39.000000
# max        3.000000     1.000000                   NaN   NaN    80.000000
#
#               sibsp        parch    ticket         fare        cabin embarked  \
# ...

# %%
data[data.notnull()]
# Out:
#       pclass  survived                                             name  \
# 0          1         1                    Allen, Miss. Elisabeth Walton
# 1          1         1                   Allison, Master. Hudson Trevor
# 2          1         0                     Allison, Miss. Helen Loraine
# 3          1         0             Allison, Mr. Hudson Joshua Creighton
# 4          1         0  Allison, Mrs. Hudson J C (Bessie Waldo Daniels)
# ...      ...       ...                                              ...
# 1304       3         0                             Zabour, Miss. Hileni
# 1305       3         0                            Zabour, Miss. Thamine
# 1306       3         0                        Zakarian, Mr. Mapriededer
# 1307       3         0                              Zakarian, Mr. Ortin
# 1308       3         0                               Zimmerman, Mr. Leo
#
#          sex      age  sibsp  parch  ticket      fare    cabin embarked boat  \
# ...
