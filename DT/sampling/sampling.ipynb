# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiziferr/machine_learning/blob/main/DT/sampling.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
url = 'https://raw.githubusercontent.com/Kaiziferr/datasets/main/diabetes.csv'
data = pd.read_csv(url)
data.head(5)
# Out:
#    Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0            6      148             72             35        0  33.6
# 1            1       85             66             29        0  26.6
# 2            8      183             64              0        0  23.3
# 3            1       89             66             23       94  28.1
# 4            0      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Age  Outcome
# 0                     0.627   50        1
# 1                     0.351   31        0
# 2                     0.672   32        1
# 3                     0.167   21        0
# 4                     2.288   33        1

# %% [markdown]
# # **Muestreo Aleatorio**
# ---

# %%
aleatorio = data.sample(n=5)
aleatorio
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 388            5      144             82             26      285  32.0
# 403            9       72             78             25        0  31.6
# 482            4       85             58             22       49  27.8
# 28            13      145             82             19      110  22.2
# 30             5      109             75             26        0  36.0
#
#      DiabetesPedigreeFunction  Age  Outcome
# 388                     0.452   58        1
# 403                     0.280   38        0
# 482                     0.306   28        0
# 28                      0.245   57        0
# 30                      0.546   60        0

# %%
aleatorio = data.sample(frac=0.25)
display(aleatorio.shape, data.shape)
# Out:
# (192, 9)
# (768, 9)

# %%
data.shape[0] * 0.25
# Out:
# 192.0

# %%
aleatorio
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 665            1      112             80             45      132  34.8
# 106            1       96            122              0        0  22.4
# 51             1      101             50             15       36  24.2
# 70             2      100             66             20       90  32.9
# 755            1      128             88             39      110  36.5
# ..           ...      ...            ...            ...      ...   ...
# 525            3       87             60             18        0  21.8
# 340            1      130             70             13      105  25.9
# 733            2      106             56             27      165  29.0
# 331            2       87             58             16       52  32.7
# 165            6      104             74             18      156  29.9
#
#      DiabetesPedigreeFunction  Age  Outcome
# 665                     0.217   24        0
# 106                     0.207   27        0
# 51                      0.526   26        0
# 70                      0.867   28        1
# 755                     1.057   37        1
# ..                        ...  ...      ...
# 525                     0.444   21        0
# 340                     0.472   22        0
# 733                     0.426   22        0
# 331                     0.166   25        0
# 165                     0.722   41        1
#
# [192 rows x 9 columns]

# %% [markdown]
# # **Muestreo sistematico**
# ---
# No es posible determinar una función para todos los casos, ya que el muestreo sistematico dependera de la regla que se usara como condición.

# %%
def systematic_sampling(data:pd.Series, step:int=3)->pd.DataFrame:
  """return data by systematic_sampling"""
  indexes = np.arange(0, len(data), step=3)
  systematic_sample = data.iloc[indexes]
  return systematic_sample

# %%
systematic_sample = systematic_sampling(data, 3)
systematic_sample
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35        0  33.6
# 3              1       89             66             23       94  28.1
# 6              3       78             50             32       88  31.0
# 9              8      125             96              0        0   0.0
# 12            10      139             80              0        0  27.1
# ..           ...      ...            ...            ...      ...   ...
# 753            0      181             88             44      510  43.3
# 756            7      137             90             41        0  32.0
# 759            6      190             92              0        0  35.5
# 762            9       89             62              0        0  22.5
# 765            5      121             72             23      112  26.2
#
#      DiabetesPedigreeFunction  Age  Outcome
# 0                       0.627   50        1
# 3                       0.167   21        0
# 6                       0.248   26        1
# 9                       0.232   54        1
# 12                      1.441   57        0
# ..                        ...  ...      ...
# 753                     0.222   26        1
# 756                     0.391   39        0
# 759                     0.278   66        1
# 762                     0.142   33        0
# 765                     0.245   30        0
#
# [256 rows x 9 columns]

# %% [markdown]
# # **Muestreo estratificado**
# ---
