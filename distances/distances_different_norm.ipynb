# %% [markdown]
# <a href="https://colab.research.google.com/github/Kaiziferr/machine_learning/blob/main/distances/distances_different_norm.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from scipy.spatial import distance_matrix
import matplotlib.pyplot as plt
import seaborn as sns

# %%
url = 'https://raw.githubusercontent.com/joanby/\
python-ml-course/master/datasets/movies/movies.csv'
data = pd.read_csv(url, sep=';')

# %%
data
# Out:
#    user_id  star_wars  lord_of_the_rings  harry_potter
# 0        1        1.2                4.9           2.1
# 1        2        2.1                8.1           7.9
# 2        3        7.4                3.0           9.9
# 3        4        5.6                0.5           1.8
# 4        5        1.5                8.3           2.6
# 5        6        2.5                3.7           6.5
# 6        7        2.0                8.2           8.5
# 7        8        1.8                9.3           4.5
# 8        9        2.6                1.7           3.1
# 9       10        1.5                4.7           2.3

# %% [markdown]
# - Todas las peliculas estan valoradas de 1-10

# %%
movies = data.columns.values.tolist()[1:]
movies
# Out:
# ['star_wars', 'lord_of_the_rings', 'harry_potter']

# %% [markdown]
# **Distances**

# %%
# Qué norma p de Minkowski utilizar.
dd1 = distance_matrix(data[movies], data[movies], p=1) # Manhattan
dd2 = distance_matrix(data[movies], data[movies], p=2) # Euclidian
dd10 = distance_matrix(data[movies], data[movies], p=10)

# %%
dd1 = pd.DataFrame(dd1, index=data['user_id'], columns = data['user_id'])
cm = sns.light_palette('red', as_cmap=True)
dd1.style.background_gradient(cmap=cm)
# Out:
# <style type="text/css">
# #T_44f8d_row0_col0, #T_44f8d_row1_col1, #T_44f8d_row2_col2, #T_44f8d_row3_col3, #T_44f8d_row4_col4, #T_44f8d_row5_col5, #T_44f8d_row6_col6, #T_44f8d_row7_col7, #T_44f8d_row8_col8, #T_44f8d_row9_col9 {
#   background-color: #f3f0f0;
#   color: #000000;
# }
# #T_44f8d_row0_col1 {
#   background-color: #fa6666;
#   color: #f1f1f1;
# }
# #T_44f8d_row0_col2 {
#   background-color: #fd2121;
#   color: #f1f1f1;
# }
# #T_44f8d_row0_col3 {
#   background-color: #f97777;
#   color: #f1f1f1;
# }
# #T_44f8d_row0_col4 {
#   background-color: #f6b9b9;
#   color: #000000;
# }
# #T_44f8d_row0_col5 {
#   background-color: #fa5959;
#   color: #f1f1f1;
# }
# #T_44f8d_row0_col6 {
#   background-color: #fa6464;
#   color: #f1f1f1;
# }
# #T_44f8d_row0_col7, #T_44f8d_row3_col8, #T_44f8d_row5_col8 {
#   background-color: #f88989;
#   color: #f1f1f1;
# }
# #T_44f8d_row0_col8, #T_44f8d_row5_col0 {
#   background-color: #f88888;
#   color: #f1f1f1;
# }
# ...

# %% [markdown]
# - El usuario 3, es el que tiene mayor disimilitud con respecto al resto de usuarios
# - Los usuarios 10 y 1 se parecen, tuvieron calificaciones similares
# - Los usuarios 2 y 7 se parecen, tuvieron calificaciones similares
# - Los usuarios 2 y 7 se parecen, tuvieron calificaciones similares
# - El usuario 4 no tiene una similitud con otros usuarios, pero el mas parecido es el 9

# %%
pd.DataFrame(dd2, index=data['user_id'])
# Out:
#                  0          1          2          3          4         5  \
# user_id
# 1         0.000000   6.685058  10.143471   6.229767   3.449638  4.742362
# 2         6.685058   0.000000   7.622336  10.354709   5.337602  4.634652
# 3        10.143471   7.622336   0.000000   8.666026  10.779147  6.004998
# 4         6.229767  10.354709   8.666026   0.000000   8.848164  6.476110
# 5         3.449638   5.337602  10.779147   8.848164   0.000000  6.113101
# 6         4.742362   4.634652   6.004998   6.476110   6.113101  0.000000
# 7         7.244998   0.616441   7.626270  10.823123   5.921993  4.949747
# 8         5.047772   3.618011  10.010494   9.958414   2.167948  5.987487
# 9         3.633180   8.015610   8.424369   3.482815   6.709694  3.945884
# 10        0.412311   6.578754   9.770363   5.890671   3.612478  4.431704
#
#                  6          7         8         9
# user_id
# 1         7.244998   5.047772  3.633180  0.412311
# ...

# %%
pd.DataFrame(dd10, index=data['user_id'])
# Out:
#                 0         1         2         3         4         5         6  \
# user_id
# 1        0.000000  5.801514  7.875189  4.715803  3.400000  4.400003  6.400850
# 2        5.801514  0.000000  5.582463  7.680689  5.300000  4.400005  0.600000
# 3        7.875189  5.582463  0.000000  8.100007  7.408914  4.912532  5.689450
# 4        4.715803  7.680689  8.100007  0.000000  7.801255  4.717102  7.873307
# 5        3.400000  5.300000  7.408914  7.801255  0.000000  4.681464  5.900000
# 6        4.400003  4.400005  4.912532  4.717102  4.681464  0.000000  4.500135
# 7        6.400850  0.600000  5.689450  7.873307  5.900000  4.500135  0.000000
# 8        4.401025  3.400010  6.570254  8.800205  1.900310  5.600019  4.000001
# 9        3.200085  6.435159  6.820602  3.000101  6.600000  3.401683  6.595259
# 10       0.301025  5.603800  7.658364  4.450759  3.600000  4.200000  6.202035
#
#                 7         8         9
# user_id
# 1        4.401025  3.200085  0.301025
# ...

# %% [markdown]
# **Plot**
# ---

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection="3d")
ax.scatter(
    xs = data['star_wars'],
    ys = data['lord_of_the_rings'],
    zs = data['harry_potter']
)
plt.show()
